# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from tqdm import tqdm
import numpy as np
import time
import time
from tqdm import tqdm
from itertools import chain

# %%
URL = 'https://www.fifplay.com/fifa-22/players/?page={}'

# %%
data = []
for page_num in tqdm(range(1,123)):
    current_page=URL.format(page_num)
    page = requests.get(current_page)
    soup = BeautifulSoup(page.content, "html.parser")
    table = soup.find('table', attrs={'class':'table listing table-vert-align table-nopadding table-hover table-striped'})
    table_body = table.find('tbody')

    rows = table_body.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 122/122 [04:43<00:00,  2.32s/it]

# %%
data=pd.DataFrame(data)
data
# Out:
#       0                       1        2        3        4        5        6   \
# 0     93        Lionel Messi\nRW  PAC\n85  SHO\n92  PAS\n91  DRI\n95  DEF\n38
# 1     92   Cristiano Ronaldo\nST  PAC\n89  SHO\n93  PAS\n81  DRI\n89  DEF\n35
# 2     91    Kevin De Bruyne\nCAM  PAC\n76  SHO\n86  PAS\n93  DRI\n88  DEF\n64
# 3     91  Robert Lewandowski\nST  PAC\n78  SHO\n91  PAS\n78  DRI\n86  DEF\n43
# 4     91           Neymar Jr\nLW  PAC\n91  SHO\n85  PAS\n86  DRI\n94  DEF\n36
# ...   ..                     ...      ...      ...      ...      ...      ...
# 6054  48       Laurie Walker\nGK  DIV\n51  POS\n46  HAN\n47  REF\n48  KIC\n43
# 6055  48       Laurie Walker\nGK  DIV\n51  POS\n46  HAN\n47  REF\n48  KIC\n43
# 6056  48             Zhen Ma\nGK  DIV\n49  POS\n44  HAN\n47  REF\n46  KIC\n45
# 6057  48          Jack Smith\nCM  PAC\n66  SHO\n36  PAS\n46  DRI\n48  DEF\n44
# 6058  48        Jingxuan Lan\nCB  PAC\n73  SHO\n33  PAS\n36  DRI\n39  DEF\n49
#
#            7    8     9     10     11
# 0     PHY\n65  ★ 4   Med   Low   Left
# 1     PHY\n77  ★ 5  High   Low  Right
# 2     PHY\n78  ★ 4  High  High  Right
# 3     PHY\n82  ★ 4  High   Med  Right
# 4     PHY\n59  ★ 5  High   Med  Right
# ...       ...  ...   ...   ...    ...
# 6054  SPD\n33  ★ 1   Med   Med  Right
# 6055  SPD\n33  ★ 1   Med   Med  Right
# 6056  SPD\n54  ★ 1   Med   Med  Right
# 6057  PHY\n67  ★ 2   Med   Med  Right
# 6058  PHY\n49  ★ 2   Med   Med  Right
#
# [6059 rows x 12 columns]

# %%
data.to_excel('FIFA_22.xlsx', index=False, header=True)

# %%
DATA = pd.read_excel('../Cleaned_FIFA_players.xlsx', engine='openpyxl')

# %%
DATA['ref_url1']=DATA['ref_url'].apply(lambda x: 'https://www.fifplay.com/fifa-22/players'+str(x)[29:])

# %%
found_url = []
not_found = []
df_position=pd.DataFrame()
df_info=pd.DataFrame()
for URL in tqdm(DATA['ref_url1'][:5]):
    try:
        info_data=[]
        current_page=URL
        page = requests.get(current_page)
        soup = BeautifulSoup(page.content, "html.parser")
        table = soup.find('table', attrs={'class':['table table-details bg-white small']})
        table_body = table.find('tbody')
        rows = table_body.find_all('tr')
        for row in rows:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            info_data.append([ele for ele in cols if ele])
        info_data=list(chain.from_iterable(info_data))
        info_data=info_data+[current_page]
        df_info = df_info.append(pd.DataFrame([info_data]), ignore_index=True)
        
        table = soup.findAll('table', attrs={'class':['table table-details bg-white small']})[1]
        table_body = table.find('tbody')
        rows = table_body.find_all('tr')
        for row in rows:
            cols = row.find_all('td')
            cols = [ele.text.strip() for ele in cols]
            position_data.append([ele for ele in cols if ele])
        position_data=list(chain.from_iterable(position_data))
        position_data=position_data+[current_page]
        df_position = df_position.append(pd.DataFrame([position_data]), ignore_index=True)
            
    except:
        not_found.append(URL)
# Out:
#   1%|▋                                                                                | 8/1000 [00:11<21:57,  1.33s/it]

# %%
df_position
# Out:
#                               0                    1                  2  \
# 0                  Lionel Messi  Age 33 (06-24-1987)  Overall Rating 93
# 1  C. Ronaldo dos Santos Aveiro  Age 35 (02-05-1985)  Overall Rating 92
#
#                            3                          4                  5  \
# 0  Club  Paris Saint-Germain  League  Ligue 1 Conforama  Nation  Argentina
# 1    Club  Manchester United     League  Premier League   Nation  Portugal
#
#                                                    6
# 0  https://www.fifplay.com/fifa-22/players/158023...
# 1  https://www.fifplay.com/fifa-22/players/20801/...

# %%
from itertools import chain
position_data = []

current_page=DATA['ref_url1'][1]
page = requests.get(current_page)
soup = BeautifulSoup(page.content, "html.parser")
table = soup.findAll('table', attrs={'class':['table table-details bg-white small']})[1]
table_body = table.find('tbody')
rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    deta=[ele for ele in cols if ele]
    position_data.append(deta)

# %%
position_data=list(chain.from_iterable(position_data))

# %%
#position_data=position_data.append(current_page[0])

# %%
position_data=position_data+[current_page]

# %%
df=pd.DataFrame()

# %%
df = df.append(pd.DataFrame([position_data]), ignore_index=True)

# %%
df
# Out:
#                        0                               1                    2  \
# 0  Position Striker (ST)  Height / Weight 187 cm / 83 kg  Preferred FootRight
#
#                 3                         4                        5  \
# 0  Weak Foot4 / 5  Attacking Work Rate High  Defensive Work Rate Low
#
#                                                    6
# 0  https://www.fifplay.com/fifa-22/players/20801/...
